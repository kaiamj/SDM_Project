# %%
from config.Neo_connect import Neo4jConnection
import pandas as pd
import config.db_settings as db_config

# stablish connection with neo4j
conn = Neo4jConnection(uri="bolt://localhost:7687", user=db_config.USER, pwd=db_config.PASSWORD)
#result = conn.query('create database {}'.format(DATABASE))

# %%
import glob
import re
import pandas as pd
import numpy as np

# %% [markdown]
# ## company

# %%
comp_ID = pd.read_csv("data/stock_data.csv")

# %%
comp_ID[['company_ID','symbol','companyName']].to_csv("data_/companyN.csv")

# %%
company = pd.read_csv("data_/companyN.csv")

# %% [markdown]
# ## stocks

# %%
stocks = glob.glob("processed_stocks/*")

# %%
stock = pd.DataFrame(columns = ['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID'])

# %%
#symbol,companyName,lastPrice,dayHigh,dayLow,closePrice,open,timestamp_ID,stock_market_ID,company_ID
time_count = 0 

for i in range(len(stocks)):
    minute = re.findall(r"\d+",stocks[i])
    if int(minute[1])%3 == 0:  # get every 3rd minute to match with tweet data
        print(minute[1])
        print(stocks[i])
        st_data = pd.read_csv(stocks[i])
        st_data['timestamp_ID'] = int(time_count)
        st_data['stock_market_ID'] = 1 
        st_data['company_ID'] = 0
        for j in range(len(company)):
            st_data['company_ID'][j] = j
            
        stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
        time_count = time_count + 1
# Out:
# 0
# processed_stocks\stock_data_10_0.csv
# 12
# processed_stocks\stock_data_10_12.csv
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# 15
# processed_stocks\stock_data_10_15.csv
# 18
# processed_stocks\stock_data_10_18.csv
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# 21
# processed_stocks\stock_data_10_21.csv
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 24
# processed_stocks\stock_data_10_24.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 27
# processed_stocks\stock_data_10_27.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 3
# processed_stocks\stock_data_10_3.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# 30
# processed_stocks\stock_data_10_30.csv
# 33
# processed_stocks\stock_data_10_33.csv
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# 36
# processed_stocks\stock_data_10_36.csv
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 39
# processed_stocks\stock_data_10_39.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 42
# processed_stocks\stock_data_10_42.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 45
# processed_stocks\stock_data_10_45.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# 48
# processed_stocks\stock_data_10_48.csv
# 51
# processed_stocks\stock_data_10_51.csv
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 54
# processed_stocks\stock_data_10_54.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 57
# processed_stocks\stock_data_10_57.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 6
# processed_stocks\stock_data_10_6.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)
# <ipython-input-27-6ae238159e44>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_data['company_ID'][j] = j
# 9
# processed_stocks\stock_data_10_9.csv
# <ipython-input-27-6ae238159e44>:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock = stock.append(st_data[['symbol','lastPrice','dayHigh','dayLow','closePrice','open','timestamp_ID','stock_market_ID','company_ID']],ignore_index = True)

# %%
stock.to_csv("data_/stock_data.csv")

# %%
stock["timestamp_ID"].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## stock market

# %%
stock_market = pd.DataFrame(columns= ["ID","country","stock_name"])

# %%
stock_market = stock_market.append({"ID":1,"country":"INDIA","stock_name":"NSE"},ignore_index=True)
# Out:
# <ipython-input-44-1ca4daeac704>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   stock_market = stock_market.append({"ID":1,"country":"INDIA","stock_name":"NSE"},ignore_index=True)

# %%
stock_market.head()
# Out:
#   ID country stock_name
# 0  1   INDIA        NSE

# %%
stock_market.to_csv("data_/stock_market.csv")

# %% [markdown]
# ## timestamps

# %%
import datetime
from datetime import datetime

# %%
d = '1'
timestamp = pd.Timestamp('2022-6-2 '+d+':00:00')
timestamp
# Out:
# Timestamp('2022-06-02 01:00:00')

# %%
time_ = pd.DataFrame(columns = ["ID","year","month","day","hour","timestamp"])

# %%
for i in range(0,20,1):
    print(i)

   
    timestamp = pd.Timestamp('2022-6-2 '+str(i)+':00:00')
    print(timestamp)
    time_ = time_.append({"ID":i,"year":2022,"month":6,"day":2,"hour":i,"timestamp":timestamp},ignore_index = True)

# %%
time_.head()
# Out:
#   ID  year month day hour            timestamp
# 0  0  2022     6   2    0  2022-06-02 00:00:00
# 1  1  2022     6   2    1  2022-06-02 01:00:00
# 2  2  2022     6   2    2  2022-06-02 02:00:00
# 3  3  2022     6   2    3  2022-06-02 03:00:00
# 4  4  2022     6   2    4  2022-06-02 04:00:00

# %%
time_.to_csv("data_/time.csv")

# %% [markdown]
# ## tweets

# %%
import json
import random

# %%
t_file = glob.glob("processed_data_stream/*")

# %%
tweets = pd.DataFrame(columns = ["company_name","text","support_Count","rank","sentiment","polarity","userID","mentioned_userID","timestamp_ID","company_ID","tweet_ID"])

# %%
#company_name,text,support_Count,rank,sentiment,polarity,user,mentioned_user,timestamp_ID,company_ID,tweet_ID
time_count = 0 

for k in range(len(t_file)):
    with open(t_file[k],encoding="utf8") as f:
        data = json.load(f)
        
    for i in range(len(data)):
        company_name = json.dumps(data[i]["companies"], ensure_ascii=False, indent=4)
        company_name=company_name.replace("\'","").replace("\"","")
        print(company_name)
    #flx = json.dumps(data[0]["top_tweets"]["text"], ensure_ascii=False, indent=4)
        #st_data['timestamp_ID'] = time_count
        for j in range(len(data[i]["top_tweets"])):
            text = json.dumps(data[i]["top_tweets"][j]["text"], ensure_ascii=False, indent=0)
            text=text.replace("\'","").replace("\"","")
            print(text)
            support_count = json.dumps(data[i]["top_tweets"][j]["support_count"], ensure_ascii=False, indent=0)
            support_count=float(support_count.replace("\'","").replace("\"",""))
            print(type(support_count))
            rank = json.dumps(data[i]["top_tweets"][j]["rank"], ensure_ascii=False, indent=0)
            rank=float(rank.replace("\'","").replace("\"",""))
            sentiment = json.dumps(data[i]["top_tweets"][j]["sentiment"], ensure_ascii=False, indent=4)
            sentiment=float(sentiment.replace("\'","").replace("\"",""))
            polarity = json.dumps(data[i]["top_tweets"][j]["polarity"], ensure_ascii=False, indent=4)
            polarity=float(polarity.replace("\'","").replace("\"",""))
        
            tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
                                   #"userID":random.sample(range(1, 30), 1), "mentioned_userID":random.sample(range(32, 80), 3)},ignore_index=True)
     
    time_count = time_count + 1
# Out:
# IOC
# You know we got to finish the menu with something sweet for the @bts_bighit event at @AllegiantStadm ! Presenting Green Tea Infused Soft Chocolate, Coconut Tapioca &amp; Dragon 🐉 Fruit. Next time Im doing a purple dessert for the #BTSARMY  💜 🙏 #bts https://t.co/7gpC3irMNE
# <class 'float'>
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# #Zomato introduces a food quality policy for restaurants w.e.f April 18\n\n@zomato to disable restaurants found with severe food quality complaints from its platform.\n\n@Shilparanipeta reports https://t.co/fNM3bbEHz9
# <class 'float'>
# GAIL
# the prime rib sandwich “swimming in horse radish and mustard” at hot stove club concession ($19+) is a fave for longtime raptors fans @SavelSells and @angelynsayshi’s mama gail chong. https://t.co/LDiuJuN8gn https://t.co/5a6sqFqKGR
# <class 'float'>
# ITC
# 8 years of big talk has resulted in India having ONLY 8 DAYS of coal stocks.\n\nModi ji, stagflation is looming. Power cuts will crush small industries, leading to more job losses.\n\nSwitch off the bulldozers of hate and switch on the power plants! https://t.co/CiqP9SlHMx
# <class 'float'>
# JUST IN: 🇮🇳 India’s Union Minister of Finance says the biggest risk of #Bitcoin and #crypto is money laundering, terror financing.
# <class 'float'>
# HDFC
# 😂😭Best meme on #hdfcbank and #HDFC merger so far! Via @vimsicle \n#RRR #Naatu https://t.co/rZ77K4Hvb2
# <class 'float'>
# So much of social media, e-com, mails, e comm sites, apps - Netflix, Amazon, Hotstar, hdfc, youtube, axis, I have no more password combinations left in me🤔🤨🙇‍♂️💭 https://t.co/wZmrZzWt6K
# <class 'float'>
# Why the Punjab Police service account has been given to @HDFC_Bank despite having number of PSUs. \n\nI request the CM @BhagwantMann &amp; @HarpalCheemaMLA to look into this.\n\n#hdfcbank
# <class 'float'>
# RELIANCE
# The EW suite developed by #DRDO will be produced by #BEL, Hyderabad for #IAF in a recently concluded contract. A major boost to the spirit of #AatmanirbharBharat and realization of journey towards self reliance.\n@PMOIndia @DefenceMinIndia @SpokespersonMoD
# <class 'float'>
# There are many possible critiques of Pakistan’s reliance on IMF/foreign aid, but we are outraging over how mere admission of such dependence insults our national pride\n\nFamily, community, nation - our destructive obsession with defending “ghairat” is frighteningly easy to exploit
# <class 'float'>
# Demand Destruction happening now in the Telecom space as price elasticity of demand kicks in.\n\nreliance Jio lost 2 crore customers in the last two months after a steep tariff hike. https://t.co/QbiErtUrAB
# <class 'float'>
# When I told German politicians and officials reliance on Russian gas was a catastrophic error answer invariably was: “We know Russia better than you”
# <class 'float'>
# This important stride in healthcare sector truly symbolizes Honble PM Shri Narendra Modis vision of self-reliance, achieving excellence in modern health facilities for remote locations and reducing urban-rural divide to deliver services at peoples doorstep.
# <class 'float'>
# ITC
# The IOC will release 6,000 metric tonnes of diesel to #SriLanka as it pitches in to mitigate the spike in power cuts in the island nation, which is facing an unprecedented economic and energy crisis, officials in #Colombo said.\nhttps://t.co/rNK72swp2q
# <class 'float'>
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# ZOMATO
# #Zomato introduces a food quality policy for restaurants w.e.f April 18\n\n@zomato to disable restaurants found with severe food quality complaints from its platform.\n\n@Shilparanipeta reports https://t.co/fNM3bbEHz9
# <class 'float'>
# RELIANCE
# Turkey and Deutsche Bank are in the final stages of talks for a pioneering $1.1 billion loan to finance LNG purchases that will reduce the country’s reliance on Russian imports, sources say https://t.co/WnWVaSs1ob
# <class 'float'>
# GLAND

# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# <ipython-input-6-4f9c84e46abe>:28: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tweets = tweets.append({"company_name":company_name,"text":text,"support_Count":support_count,"rank":rank,"sentiment" :sentiment,"polarity":polarity,"timestamp_ID":int(time_count)},ignore_index=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-4f9c84e46abe> in <module>
#       7
#       8     for i in range(len(data)):
# ----> 9         company_name = json.dumps(data[i]["companies"], ensure_ascii=False, indent=4)
#      10         company_name=company_name.replace("\'","").replace("\"","")
#      11         print(company_name)
#
# KeyError: 'companies'

# %%
tweets
# Out:
#     company_name                                               text  \
# 0            IOC  You know we got to finish the menu with someth...
# 1           GAIL  75 years old legend gail falkenberg keeps tenn...
# 2            ITC  I’m here with a new friend…an amazing beekeepe...
# 3            ITC  💥 \I’m getting calls from these really large i...
# 4         ZOMATO  How #Twitter came together to help a #zomato d...
# ..           ...                                                ...
# 176        GLAND  Hypothyroidism is when your thyroid gland does...
# 177        GLAND  Hypothyroidism is when your thyroid gland does...
# 178        GLAND  Sweating more and being sensitive to heat are ...
# 179         GAIL  #Happydalithistorymonth! As a we open a this y...
# 180          ITC  NEW 💥 UK Finance Minister: We see “enormous po...
#
#     support_Count rank sentiment  polarity userID mentioned_userID  \
# 0          3936.0  1.0    0.0625    0.0625    NaN              NaN
# 1            90.0  1.0       0.1       0.1    NaN              NaN
# 2         27813.0  1.0  0.278788  0.278788    NaN              NaN
# 3          3300.0  2.0 -0.017857 -0.017857    NaN              NaN
# 4           650.0  1.0       0.0       0.0    NaN              NaN
# ..            ...  ...       ...       ...    ...              ...
# 176         156.0  2.0  0.071429  0.071429    NaN              NaN
# 177         118.0  3.0  0.071429  0.071429    NaN              NaN
# 178          68.0  4.0     0.325     0.325    NaN              NaN
# 179          64.0  1.0       0.3       0.3    NaN              NaN
# 180        5320.0  1.0  0.045455  0.045455    NaN              NaN
#
#     timestamp_ID company_ID  tweet_ID
# 0              0          8         0
# 1              0         17         1
# 2              0          4         2
# 3              0          4         3
# 4              1         18         4
# ..           ...        ...       ...
# 176           19         23       176
# 177           19         23       177
# 178           19         23       178
# 179           19         17       179
# 180           19          4       180
#
# [181 rows x 11 columns]

# %%
for i in range(len(company)):
    for j in range(len(tweets)):
        if (company["symbol"][i] == re.sub('"','',tweets["company_name"][j])):
            #print(stock["symbol"][i]," second ", re.sub('"','',tweet["company_name"][j])," result ",stock["symbol"][i] == re.sub('"','',tweet["company_name"][j]))
            tweets["company_ID"][j] = company.index[i]
# Out:
# <ipython-input-11-10d02ddde44a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets["company_ID"][j] = company.index[i]

# %%
tweets["tweet_ID"] = tweets.index

# %%
li = []
for i in range(len(tweets)):
    l = re.findall("@([a-zA-Z0-9]{1,15})", tweets['text'][i])
    if l:
        for item in l:
          
            li.append(item)
            print(item)

x = np.array(li)
x = np.unique(x)
# Out:
# bts
# AllegiantStadm
# WCKitchen
# Adityaaa
# zomato
# zomato
# Shilparanipeta
# zomato
# zomatocare
# FEGtoken
# joincoinio
# cvpayne
# zomato
# zomato
# zomato
# gabe
# narendramodi
# tcs
# ntpclimited
# DelhiJalBoard
# gabe
# KwasiKwarteng
# Ed
# narendramodi
# tcs
# cashapp
# CMD
# AlkaMittal
# AshokKumar
# PetroleumMin
# HardeepSPuri
# Rameswar
# narendramodi
# TalKopan
# joegarofoli
# tcs
# vimsicle
# HDFC
# BhagwantMann
# HarpalCheemaMLA
# JoeBiden
# Ed
# zomato
# zomato
# zomato
# zomatocare
# zomato
# zomatocare
# zomato
# zomatocare
# gailsiemko
# choftk
# jodster
# mov46
# gonzo
# gonny
# 959angela
# robinson4206
# SeptemberDee
# MTBTTLady
# WhatsupLiz
# daniela27
# Mother3Teresa
# tserings
# Andiecip
# SomiaQuilt
# scentlodge
# BlueJays
# yourphilarmy
# USArmy
# namcios
# terra
# vimsicle
# HDFC
# BhagwantMann
# HarpalCheemaMLA
# narendramodi
# zomato
# zomato
# zomatocare
# swiggy
# zomato
# Anshul
# UNBWHockey
# joingailsfight
# CanadasLifeline
# zomato
# zomato
# zomato
# zomato
# zomatocare
# zomato
# Mukunda
# Aish
# sabatsudeep
# zomato
# Aish
# deepigoyal
# sabatsudeep
# cvpayne
# zomato
# Mukunda
# Aish
# sabatsudeep
# zomato
# Aish
# deepigoyal
# sabatsudeep
# zomato
# zomato
# awscloud
# swiggy
# deepigoyal
# NayantaraRai
# 8pm
# grrroy
# Mukunda
# sabatsudeep
# zomato
# GetKappaXs
# prashantodas
# NextMeet
# pushpak
# invactHQs
# manishm
# Mayank23Agrawal
# Chatty111Prasad
# DDNewslive
# PaulBrandITV
# Paul12269604
# Mike
# BrightStarsFC
# Busogautdfc
# upl
# Adityaaa
# zomato
# Shilparanipeta
# SavelSells
# angelynsayshi
# vimsicle
# HDFC
# BhagwantMann
# HarpalCheemaMLA
# PMOIndia
# DefenceMinIndia
# SpokespersonMoD
# zomato
# Shilparanipeta
# switchEVglobal
# Mphasis
# Prodapt
# tvsmotorcompany
# TVSSCS
# Propertyshare3
# BYJUS
# apollotyres
# zomato
# deepigoyal
# swiggy
# zomato
# NayantaraRai
# NRAI
# KabirSuriAzure
# CCI

# %%
len(x)
# Out:
# 97

# %%
name_df = pd.DataFrame(columns = ['ID','name','followers_count'])

# %%
name_li =  ['James','Mary','Robert','Patricia','John','Jennifer','Michael','Linda','David','Elizabeth','William'
           'Barbara','Richard','Susan','Joseph','Jessica']

# %% [markdown]
# np.append(name_li,x,axis = 0)

# %%
name_df['name'] = np.append(name_li,x,axis = 0)

# %%
name_df['ID'] = name_df.index

# %%
name_df['followers_count'] = np.random.choice(np.random.randint(30, 100000), size=len(name_df))

# %%
name_df
# Out:
#       ID          name  followers_count
# 0      0         James             3616
# 1      1          Mary             9862
# 2      2        Robert             3021
# 3      3      Patricia             8222
# 4      4          John             8536
# ..   ...           ...              ...
# 107  107           upl             1144
# 108  108      vimsicle            11964
# 109  109  yourphilarmy             1557
# 110  110        zomato              483
# 111  111    zomatocare             4149
#
# [112 rows x 3 columns]

# %%
name_df.to_csv("data_/user_data.csv")

# %%
for j in name_df['name']:
    print(j)
# Out:
# James
# Mary
# Robert
# Patricia
# John
# Jennifer
# Michael
# Linda
# David
# Elizabeth
# WilliamBarbara
# Richard
# Susan
# Joseph
# Jessica
# 8pm
# 959angela
# Adityaaa
# Aish
# AlkaMittal
# AllegiantStadm
# Andiecip
# Anshul
# AshokKumar
# BYJUS
# BhagwantMann
# BlueJays
# BrightStarsFC
# Busogautdfc
# CCI
# CMD
# CanadasLifeline
# Chatty111Prasad
# DDNewslive
# DefenceMinIndia
# DelhiJalBoard
# Ed
# FEGtoken
# GetKappaXs
# HDFC
# HardeepSPuri
# HarpalCheemaMLA
# JoeBiden
# KabirSuriAzure
# KwasiKwarteng
# MTBTTLady
# Mayank23Agrawal
# Mike
# Mother3Teresa
# Mphasis
# Mukunda
# NRAI
# NayantaraRai
# NextMeet
# PMOIndia
# Paul12269604
# PaulBrandITV
# PetroleumMin
# Prodapt
# Propertyshare3
# Rameswar
# SavelSells
# SeptemberDee
# Shilparanipeta
# SomiaQuilt
# SpokespersonMoD
# TVSSCS
# TalKopan
# UNBWHockey
# USArmy
# WCKitchen
# WhatsupLiz
# angelynsayshi
# apollotyres
# awscloud
# bts
# cashapp
# choftk
# cvpayne
# daniela27
# deepigoyal
# gabe
# gailsiemko
# gonny
# gonzo
# grrroy
# invactHQs
# jodster
# joegarofoli
# joincoinio
# joingailsfight
# manishm
# mov46
# namcios
# narendramodi
# ntpclimited
# prashantodas
# pushpak
# robinson4206
# sabatsudeep
# scentlodge
# swiggy
# switchEVglobal
# tcs
# terra
# tserings
# tvsmotorcompany
# upl
# vimsicle
# yourphilarmy
# zomato
# zomatocare

# %%
tweets["userID"] =  np.random.choice(name_df[:15].ID, size=len(tweets))

# %%
for i in range(len(tweets)):
    l = re.findall("@([a-zA-Z0-9]{1,15})", tweets['text'][i])
    li = []
    if l:
        for item in l:
            for j in range(len(name_df['name'])):
                if item == name_df['name'][j]:
                    li.append(j)
                    print(item ," matched ",name_df['name'][j], "  assigning id " ,j )
                    continue 
    tweets['mentioned_userID'][i] = li
    print(i ," tweet has ",li )
# Out:
# bts  matched  bts   assigning id  75
# AllegiantStadm  matched  AllegiantStadm   assigning id  20
# 0  tweet has  [75, 20]
# 1  tweet has  []
# WCKitchen  matched  WCKitchen   assigning id  70
# 2  tweet has  [70]
# 3  tweet has  []
# Adityaaa  matched  Adityaaa   assigning id  17
# 4  tweet has  [17]
# zomato  matched  zomato   assigning id  110
# 5  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# Shilparanipeta  matched  Shilparanipeta   assigning id  63
# 6  tweet has  [110, 63]
# zomato  matched  zomato   assigning id  110
# zomatocare  matched  zomatocare   assigning id  111
# 7  tweet has  [110, 111]
# FEGtoken  matched  FEGtoken   assigning id  37
# joincoinio  matched  joincoinio   assigning id  89
# 8  tweet has  [37, 89]
# cvpayne  matched  cvpayne   assigning id  78
# 9  tweet has  [78]
# zomato  matched  zomato   assigning id  110
# 10  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# 11  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# 12  tweet has  [110]
# 13  tweet has  []
# 14  tweet has  []
# 15  tweet has  []
# <ipython-input-127-98ddb1f1f3ce>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets['mentioned_userID'][i] = li
# 16  tweet has  []
# 17  tweet has  []
# 18  tweet has  []
# 19  tweet has  []
# 20  tweet has  []
# 21  tweet has  []
# 22  tweet has  []
# 23  tweet has  []
# 24  tweet has  []
# 25  tweet has  []
# 26  tweet has  []
# gabe  matched  gabe   assigning id  81
# 27  tweet has  [81]
# 28  tweet has  []
# 29  tweet has  []
# 30  tweet has  []
# 31  tweet has  []
# narendramodi  matched  narendramodi   assigning id  94
# 32  tweet has  [94]
# tcs  matched  tcs   assigning id  103
# 33  tweet has  [103]
# 34  tweet has  []
# 35  tweet has  []
# 36  tweet has  []
# ntpclimited  matched  ntpclimited   assigning id  95
# DelhiJalBoard  matched  DelhiJalBoard   assigning id  35
# 37  tweet has  [95, 35]
# 38  tweet has  []
# 39  tweet has  []
# 40  tweet has  []
# 41  tweet has  []
# 42  tweet has  []
# gabe  matched  gabe   assigning id  81
# 43  tweet has  [81]
# 44  tweet has  []
# 45  tweet has  []
# 46  tweet has  []
# KwasiKwarteng  matched  KwasiKwarteng   assigning id  44
# 47  tweet has  [44]
# 48  tweet has  []
# 49  tweet has  []
# 50  tweet has  []
# Ed  matched  Ed   assigning id  36
# 51  tweet has  [36]
# 52  tweet has  []
# 53  tweet has  []
# 54  tweet has  []
# 55  tweet has  []
# narendramodi  matched  narendramodi   assigning id  94
# 56  tweet has  [94]
# 57  tweet has  []
# tcs  matched  tcs   assigning id  103
# 58  tweet has  [103]
# cashapp  matched  cashapp   assigning id  76
# 59  tweet has  [76]
# 60  tweet has  []
# CMD  matched  CMD   assigning id  30
# AlkaMittal  matched  AlkaMittal   assigning id  19
# AshokKumar  matched  AshokKumar   assigning id  23
# PetroleumMin  matched  PetroleumMin   assigning id  57
# HardeepSPuri  matched  HardeepSPuri   assigning id  40
# Rameswar  matched  Rameswar   assigning id  60
# 61  tweet has  [30, 19, 23, 57, 40, 60]
# 62  tweet has  []
# 63  tweet has  []
# 64  tweet has  []
# 65  tweet has  []
# 66  tweet has  []
# 67  tweet has  []
# narendramodi  matched  narendramodi   assigning id  94
# 68  tweet has  [94]
# TalKopan  matched  TalKopan   assigning id  67
# joegarofoli  matched  joegarofoli   assigning id  88
# 69  tweet has  [67, 88]
# 70  tweet has  []
# 71  tweet has  []
# tcs  matched  tcs   assigning id  103
# 72  tweet has  [103]
# vimsicle  matched  vimsicle   assigning id  108
# 73  tweet has  [108]
# 74  tweet has  []
# HDFC  matched  HDFC   assigning id  39
# BhagwantMann  matched  BhagwantMann   assigning id  25
# HarpalCheemaMLA  matched  HarpalCheemaMLA   assigning id  41
# 75  tweet has  [39, 25, 41]
# 76  tweet has  []
# 77  tweet has  []
# 78  tweet has  []
# 79  tweet has  []
# 80  tweet has  []
# 81  tweet has  []
# JoeBiden  matched  JoeBiden   assigning id  42
# 82  tweet has  [42]
# Ed  matched  Ed   assigning id  36
# 83  tweet has  [36]
# 84  tweet has  []
# 85  tweet has  []
# 86  tweet has  []
# zomato  matched  zomato   assigning id  110
# 87  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# 88  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# zomatocare  matched  zomatocare   assigning id  111
# 89  tweet has  [110, 111]
# zomato  matched  zomato   assigning id  110
# zomatocare  matched  zomatocare   assigning id  111
# 90  tweet has  [110, 111]
# zomato  matched  zomato   assigning id  110
# zomatocare  matched  zomatocare   assigning id  111
# 91  tweet has  [110, 111]
# 92  tweet has  []
# 93  tweet has  []
# 94  tweet has  []
# 95  tweet has  []
# 96  tweet has  []
# gailsiemko  matched  gailsiemko   assigning id  82
# choftk  matched  choftk   assigning id  77
# jodster  matched  jodster   assigning id  87
# mov46  matched  mov46   assigning id  92
# gonzo  matched  gonzo   assigning id  84
# gonny  matched  gonny   assigning id  83
# 959angela  matched  959angela   assigning id  16
# robinson4206  matched  robinson4206   assigning id  98
# SeptemberDee  matched  SeptemberDee   assigning id  62
# MTBTTLady  matched  MTBTTLady   assigning id  45
# WhatsupLiz  matched  WhatsupLiz   assigning id  71
# daniela27  matched  daniela27   assigning id  79
# Mother3Teresa  matched  Mother3Teresa   assigning id  48
# tserings  matched  tserings   assigning id  105
# Andiecip  matched  Andiecip   assigning id  21
# SomiaQuilt  matched  SomiaQuilt   assigning id  64
# scentlodge  matched  scentlodge   assigning id  100
# BlueJays  matched  BlueJays   assigning id  26
# 97  tweet has  [82, 77, 87, 92, 84, 83, 16, 98, 62, 45, 71, 79, 48, 105, 21, 64, 100, 26]
# 98  tweet has  []
# 99  tweet has  []
# 100  tweet has  []
# yourphilarmy  matched  yourphilarmy   assigning id  109
# USArmy  matched  USArmy   assigning id  69
# 101  tweet has  [109, 69]
# 102  tweet has  []
# 103  tweet has  []
# namcios  matched  namcios   assigning id  93
# 104  tweet has  [93]
# terra  matched  terra   assigning id  104
# 105  tweet has  [104]
# vimsicle  matched  vimsicle   assigning id  108
# 106  tweet has  [108]
# 107  tweet has  []
# HDFC  matched  HDFC   assigning id  39
# BhagwantMann  matched  BhagwantMann   assigning id  25
# HarpalCheemaMLA  matched  HarpalCheemaMLA   assigning id  41
# 108  tweet has  [39, 25, 41]
# 109  tweet has  []
# 110  tweet has  []
# narendramodi  matched  narendramodi   assigning id  94
# 111  tweet has  [94]
# 112  tweet has  []
# 113  tweet has  []
# zomato  matched  zomato   assigning id  110
# 114  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# zomatocare  matched  zomatocare   assigning id  111
# 115  tweet has  [110, 111]
# 116  tweet has  []
# 117  tweet has  []
# 118  tweet has  []
# 119  tweet has  []
# 120  tweet has  []
# swiggy  matched  swiggy   assigning id  101
# zomato  matched  zomato   assigning id  110
# Anshul  matched  Anshul   assigning id  22
# 121  tweet has  [101, 110, 22]
# 122  tweet has  []
# UNBWHockey  matched  UNBWHockey   assigning id  68
# joingailsfight  matched  joingailsfight   assigning id  90
# CanadasLifeline  matched  CanadasLifeline   assigning id  31
# 123  tweet has  [68, 90, 31]
# 124  tweet has  []
# 125  tweet has  []
# 126  tweet has  []
# zomato  matched  zomato   assigning id  110
# 127  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# 128  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# 129  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# zomatocare  matched  zomatocare   assigning id  111
# 130  tweet has  [110, 111]
# zomato  matched  zomato   assigning id  110
# Mukunda  matched  Mukunda   assigning id  50
# Aish  matched  Aish   assigning id  18
# sabatsudeep  matched  sabatsudeep   assigning id  99
# 131  tweet has  [110, 50, 18, 99]
# zomato  matched  zomato   assigning id  110
# Aish  matched  Aish   assigning id  18
# deepigoyal  matched  deepigoyal   assigning id  80
# sabatsudeep  matched  sabatsudeep   assigning id  99
# 132  tweet has  [110, 18, 80, 99]
# 133  tweet has  []
# 134  tweet has  []
# 135  tweet has  []
# 136  tweet has  []
# 137  tweet has  []
# cvpayne  matched  cvpayne   assigning id  78
# 138  tweet has  [78]
# zomato  matched  zomato   assigning id  110
# Mukunda  matched  Mukunda   assigning id  50
# Aish  matched  Aish   assigning id  18
# sabatsudeep  matched  sabatsudeep   assigning id  99
# 139  tweet has  [110, 50, 18, 99]
# zomato  matched  zomato   assigning id  110
# Aish  matched  Aish   assigning id  18
# deepigoyal  matched  deepigoyal   assigning id  80
# sabatsudeep  matched  sabatsudeep   assigning id  99
# 140  tweet has  [110, 18, 80, 99]
# zomato  matched  zomato   assigning id  110
# 141  tweet has  [110]
# zomato  matched  zomato   assigning id  110
# awscloud  matched  awscloud   assigning id  74
# swiggy  matched  swiggy   assigning id  101
# deepigoyal  matched  deepigoyal   assigning id  80
# NayantaraRai  matched  NayantaraRai   assigning id  52
# 142  tweet has  [110, 74, 101, 80, 52]
# 8pm  matched  8pm   assigning id  15
# grrroy  matched  grrroy   assigning id  85
# Mukunda  matched  Mukunda   assigning id  50
# sabatsudeep  matched  sabatsudeep   assigning id  99
# zomato  matched  zomato   assigning id  110
# GetKappaXs  matched  GetKappaXs   assigning id  38
# prashantodas  matched  prashantodas   assigning id  96
# NextMeet  matched  NextMeet   assigning id  53
# pushpak  matched  pushpak   assigning id  97
# invactHQs  matched  invactHQs   assigning id  86
# manishm  matched  manishm   assigning id  91
# Mayank23Agrawal  matched  Mayank23Agrawal   assigning id  46
# Chatty111Prasad  matched  Chatty111Prasad   assigning id  32
# DDNewslive  matched  DDNewslive   assigning id  33
# 143  tweet has  [15, 85, 50, 99, 110, 38, 96, 53, 97, 86, 91, 46, 32, 33]
# PaulBrandITV  matched  PaulBrandITV   assigning id  56
# Paul12269604  matched  Paul12269604   assigning id  55
# Mike  matched  Mike   assigning id  47
# 144  tweet has  [56, 55, 47]
# BrightStarsFC  matched  BrightStarsFC   assigning id  27
# Busogautdfc  matched  Busogautdfc   assigning id  28
# upl  matched  upl   assigning id  107
# 145  tweet has  [27, 28, 107]
# 146  tweet has  []
# 147  tweet has  []
# 148  tweet has  []
# 149  tweet has  []
# 150  tweet has  []
# 151  tweet has  []
# Adityaaa  matched  Adityaaa   assigning id  17
# 152  tweet has  [17]
# zomato  matched  zomato   assigning id  110
# Shilparanipeta  matched  Shilparanipeta   assigning id  63
# 153  tweet has  [110, 63]
# SavelSells  matched  SavelSells   assigning id  61
# angelynsayshi  matched  angelynsayshi   assigning id  72
# 154  tweet has  [61, 72]
# 155  tweet has  []
# 156  tweet has  []
# vimsicle  matched  vimsicle   assigning id  108
# 157  tweet has  [108]
# 158  tweet has  []
# HDFC  matched  HDFC   assigning id  39
# BhagwantMann  matched  BhagwantMann   assigning id  25
# HarpalCheemaMLA  matched  HarpalCheemaMLA   assigning id  41
# 159  tweet has  [39, 25, 41]
# PMOIndia  matched  PMOIndia   assigning id  54
# DefenceMinIndia  matched  DefenceMinIndia   assigning id  34
# SpokespersonMoD  matched  SpokespersonMoD   assigning id  65
# 160  tweet has  [54, 34, 65]
# 161  tweet has  []
# 162  tweet has  []
# 163  tweet has  []
# 164  tweet has  []
# 165  tweet has  []
# zomato  matched  zomato   assigning id  110
# Shilparanipeta  matched  Shilparanipeta   assigning id  63
# 166  tweet has  [110, 63]
# 167  tweet has  []
# 168  tweet has  []
# 169  tweet has  []
# 170  tweet has  []
# 171  tweet has  []
# switchEVglobal  matched  switchEVglobal   assigning id  102
# Mphasis  matched  Mphasis   assigning id  49
# Prodapt  matched  Prodapt   assigning id  58
# tvsmotorcompany  matched  tvsmotorcompany   assigning id  106
# TVSSCS  matched  TVSSCS   assigning id  66
# Propertyshare3  matched  Propertyshare3   assigning id  59
# BYJUS  matched  BYJUS   assigning id  24
# apollotyres  matched  apollotyres   assigning id  73
# 172  tweet has  [102, 49, 58, 106, 66, 59, 24, 73]
# zomato  matched  zomato   assigning id  110
# deepigoyal  matched  deepigoyal   assigning id  80
# 173  tweet has  [110, 80]
# swiggy  matched  swiggy   assigning id  101
# zomato  matched  zomato   assigning id  110
# NayantaraRai  matched  NayantaraRai   assigning id  52
# NRAI  matched  NRAI   assigning id  51
# KabirSuriAzure  matched  KabirSuriAzure   assigning id  43
# CCI  matched  CCI   assigning id  29
# 174  tweet has  [101, 110, 52, 51, 43, 29]
# 175  tweet has  []
# 176  tweet has  []
# 177  tweet has  []
# 178  tweet has  []
# 179  tweet has  []
# 180  tweet has  []

# %%
name_df['name'][17]
# Out:
# 'Adityaaa'

# %%
tweets
# Out:
#     company_name                                               text  \
# 0            IOC  You know we got to finish the menu with someth...
# 1           GAIL  75 years old legend gail falkenberg keeps tenn...
# 2            ITC  I’m here with a new friend…an amazing beekeepe...
# 3            ITC  💥 \I’m getting calls from these really large i...
# 4         ZOMATO  How #Twitter came together to help a #zomato d...
# ..           ...                                                ...
# 176        GLAND  Hypothyroidism is when your thyroid gland does...
# 177        GLAND  Hypothyroidism is when your thyroid gland does...
# 178        GLAND  Sweating more and being sensitive to heat are ...
# 179         GAIL  #Happydalithistorymonth! As a we open a this y...
# 180          ITC  NEW 💥 UK Finance Minister: We see “enormous po...
#
#     support_Count rank sentiment  polarity  userID mentioned_userID  \
# 0          3936.0  1.0    0.0625    0.0625       1         [75, 20]
# 1            90.0  1.0       0.1       0.1       1               []
# 2         27813.0  1.0  0.278788  0.278788       0             [70]
# 3          3300.0  2.0 -0.017857 -0.017857      14               []
# 4           650.0  1.0       0.0       0.0       2             [17]
# ..            ...  ...       ...       ...     ...              ...
# 176         156.0  2.0  0.071429  0.071429       1               []
# 177         118.0  3.0  0.071429  0.071429       9               []
# 178          68.0  4.0     0.325     0.325       3               []
# 179          64.0  1.0       0.3       0.3       0               []
# 180        5320.0  1.0  0.045455  0.045455      11               []
#
#     timestamp_ID company_ID  tweet_ID
# 0              0          8         0
# 1              0         17         1
# 2              0          4         2
# 3              0          4         3
# 4              1         18         4
# ..           ...        ...       ...
# 176           19         23       176
# 177           19         23       177
# 178           19         23       178
# 179           19         17       179
# 180           19          4       180
#
# [181 rows x 11 columns]

# %%
tweets.to_csv("data_/tweets.csv")

# %%
mentioned = tweets[["tweet_ID","mentioned_userID"]].explode("mentioned_userID").reset_index(drop=True)

# %%
mentioned.to_csv("data_/mentioned.csv")
