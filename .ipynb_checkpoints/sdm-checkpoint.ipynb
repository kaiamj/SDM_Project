# %%
from rdflib import Graph,Literal,RDF,URIRef
from rdflib.namespace import FOAF,XSD,RDFS
from rdflib import Namespace


# initialize the graph
g = Graph()

# Namespace is used for the graph general URIref
# We can add are classes (Concepts) with kg_sdm uri (/Author, /Submission, /Chair) etc.
PJ_SDM = Namespace("http://proj_sdm.org/")
# bind for the better readability
g.bind("pj_sdm",PJ_SDM)

# %%
#################################################################
#    Object Properties
#################################################################

g.add((PJ_SDM.close, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.close, RDFS.range, XSD.float))
g.add((PJ_SDM.close, RDFS.label, Literal("close")))

g.add((PJ_SDM.company_name, RDFS.domain, PJ_SDM.Company))
g.add((PJ_SDM.company_name, RDFS.range, XSD.string))
g.add((PJ_SDM.company_name, RDFS.label, Literal("company_name")))



g.add((PJ_SDM.country, RDFS.domain, PJ_SDM.Stock_market))
g.add((PJ_SDM.country, RDFS.range, XSD.string))
g.add((PJ_SDM.country, RDFS.label, Literal("country")))


g.add((PJ_SDM.has_day, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_day, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_day, RDFS.label, Literal("has_day")))


g.add((PJ_SDM.has_hour, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_hour, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_hour, RDFS.label, Literal("has_hour")))



g.add((PJ_SDM.has_month, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_month, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_month, RDFS.label, Literal("has_month")))



g.add((PJ_SDM.has_timstamp, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_timstamp, RDFS.range, XSD.string))
g.add((PJ_SDM.has_timstamp, RDFS.label, Literal("has_timstamp")))




g.add((PJ_SDM.has_year, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_year, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_year, RDFS.label, Literal("has_year")))


g.add((PJ_SDM.high, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.high, RDFS.range, XSD.float))
g.add((PJ_SDM.high, RDFS.label, Literal("high")))


g.add((PJ_SDM.in_stock_market, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.in_stock_market, RDFS.range, PJ_SDM.Stock_market))
g.add((PJ_SDM.in_stock_market, RDFS.label, Literal("in_stock_market")))


g.add((PJ_SDM.low, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.low, RDFS.range, XSD.float))
g.add((PJ_SDM.low, RDFS.label, Literal("low")))


g.add((PJ_SDM.name, RDFS.domain, PJ_SDM.Person))
g.add((PJ_SDM.name, RDFS.range, XSD.string))
g.add((PJ_SDM.name, RDFS.label, Literal("name")))


g.add((PJ_SDM.open, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.open, RDFS.range, XSD.float))
g.add((PJ_SDM.open, RDFS.label, Literal("open")))


g.add((PJ_SDM.rank, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.rank, RDFS.range, XSD.integer))
g.add((PJ_SDM.rank, RDFS.label, Literal("rank")))


g.add((PJ_SDM.related_tweet, RDFS.domain, PJ_SDM.Company))
g.add((PJ_SDM.related_tweet, RDFS.range, PJ_SDM.Tweet))
g.add((PJ_SDM.related_tweet, RDFS.label, Literal("related_tweet")))


g.add((PJ_SDM.related_user, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.related_user, RDFS.range, PJ_SDM.Mentioned_user))
g.add((PJ_SDM.related_user, RDFS.label, Literal("related_user")))


g.add((PJ_SDM.sentiment_score, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.sentiment_score, RDFS.range, XSD.float))
g.add((PJ_SDM.sentiment_score, RDFS.label, Literal("sentiment_score")))



g.add((PJ_SDM.stock_market_name, RDFS.domain, PJ_SDM.Stock_market))
g.add((PJ_SDM.stock_market_name, RDFS.range, XSD.string))
g.add((PJ_SDM.stock_market_name, RDFS.label, Literal("stock_market_name")))


g.add((PJ_SDM.stock_pricing, RDFS.domain, PJ_SDM.Company))
g.add((PJ_SDM.stock_pricing, RDFS.range, PJ_SDM.Stock_data))
g.add((PJ_SDM.stock_pricing, RDFS.label, Literal("stock_pricing")))


g.add((PJ_SDM.stock_time, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.stock_time, RDFS.range, PJ_SDM.Time))
g.add((PJ_SDM.stock_time, RDFS.label, Literal("stock_time")))


g.add((PJ_SDM.support_count, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.support_count, RDFS.range, XSD.integer))
g.add((PJ_SDM.support_count, RDFS.label, Literal("support_count")))



g.add((PJ_SDM.text, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.text, RDFS.range, XSD.string))
g.add((PJ_SDM.text, RDFS.label, Literal("text")))


g.add((PJ_SDM.tweet_by, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.tweet_by, RDFS.range, PJ_SDM.Tweet_user))
g.add((PJ_SDM.tweet_by, RDFS.label, Literal("tweet_by")))


g.add((PJ_SDM.tweet_time, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.tweet_time, RDFS.range, PJ_SDM.Time))
g.add((PJ_SDM.tweet_time, RDFS.label, Literal("tweet_time")))
# Out:
# <Graph identifier=Nd7e98ee448f443c495866ad6f9560d38 (<class 'rdflib.graph.Graph'>)>

# %%
save_format = "ttl"
file_name = "tbox.ttl"
g.serialize(file_name, format=save_format)
# Out:
# <Graph identifier=Nd7e98ee448f443c495866ad6f9560d38 (<class 'rdflib.graph.Graph'>)>

# %%
#################################################################
#    Object Properties
#################################################################

g.add((PJ_SDM.close, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.close, RDFS.range, XSD.float))
g.add((PJ_SDM.close, RDFS.label, Literal("close")))

g.add((PJ_SDM.company_name, RDFS.domain, PJ_SDM.Company))
g.add((PJ_SDM.company_name, RDFS.range, XSD.string))
g.add((PJ_SDM.company_name, RDFS.label, Literal("company_name")))



g.add((PJ_SDM.country, RDFS.domain, PJ_SDM.Stock_market))
g.add((PJ_SDM.country, RDFS.range, XSD.string))
g.add((PJ_SDM.country, RDFS.label, Literal("country")))


g.add((PJ_SDM.has_day, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_day, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_day, RDFS.label, Literal("has_day")))


g.add((PJ_SDM.has_hour, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_hour, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_hour, RDFS.label, Literal("has_hour")))



g.add((PJ_SDM.has_month, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_month, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_month, RDFS.label, Literal("has_month")))



g.add((PJ_SDM.has_timstamp, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_timstamp, RDFS.range, XSD.timestamp))
g.add((PJ_SDM.has_timstamp, RDFS.label, Literal("has_timstamp")))




g.add((PJ_SDM.has_year, RDFS.domain, PJ_SDM.Time))
g.add((PJ_SDM.has_year, RDFS.range, XSD.integer))
g.add((PJ_SDM.has_year, RDFS.label, Literal("has_year")))


g.add((PJ_SDM.high, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.high, RDFS.range, XSD.float))
g.add((PJ_SDM.high, RDFS.label, Literal("high")))


g.add((PJ_SDM.in_stock_market, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.in_stock_market, RDFS.range, PJ_SDM.Stock_market))
g.add((PJ_SDM.in_stock_market, RDFS.label, Literal("in_stock_market")))


g.add((PJ_SDM.low, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.low, RDFS.range, XSD.float))
g.add((PJ_SDM.low, RDFS.label, Literal("low")))


g.add((PJ_SDM.name, RDFS.domain, PJ_SDM.Person))
g.add((PJ_SDM.name, RDFS.range, XSD.string))
g.add((PJ_SDM.name, RDFS.label, Literal("name")))


g.add((PJ_SDM.open, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.open, RDFS.range, XSD.float))
g.add((PJ_SDM.open, RDFS.label, Literal("open")))


g.add((PJ_SDM.rank, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.rank, RDFS.range, XSD.integer))
g.add((PJ_SDM.rank, RDFS.label, Literal("rank")))


g.add((PJ_SDM.related_tweet, RDFS.domain, PJ_SDM.Company))
g.add((PJ_SDM.related_tweet, RDFS.range, PJ_SDM.Tweet))
g.add((PJ_SDM.related_tweet, RDFS.label, Literal("related_tweet")))


g.add((PJ_SDM.related_user, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.related_user, RDFS.range, PJ_SDM.Mentioned_user))
g.add((PJ_SDM.related_user, RDFS.label, Literal("related_user")))


g.add((PJ_SDM.sentiment_score, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.sentiment_score, RDFS.range, XSD.float))
g.add((PJ_SDM.sentiment_score, RDFS.label, Literal("sentiment_score")))



g.add((PJ_SDM.stock_market_name, RDFS.domain, PJ_SDM.Stock_market)
g.add((PJ_SDM.stock_market_name, RDFS.range, XSD.string))
g.add((PJ_SDM.stock_market_name, RDFS.label, Literal("stock_market_name")))


g.add((PJ_SDM.stock_pricing, RDFS.domain, PJ_SDM.Company))
g.add((PJ_SDM.stock_pricing, RDFS.range, PJ_SDM.Stock_data))
g.add((PJ_SDM.stock_pricing, RDFS.label, Literal("stock_pricing")))


g.add((PJ_SDM.stock_time, RDFS.domain, PJ_SDM.Stock_data))
g.add((PJ_SDM.stock_time, RDFS.range, PJ_SDM.Time))
g.add((PJ_SDM.stock_time, RDFS.label, Literal("stock_time")))


g.add((PJ_SDM.support_count, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.support_count, RDFS.range, XSD.integer))
g.add((PJ_SDM.support_count, RDFS.label, Literal("support_count")))



g.add((PJ_SDM.text, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.text, RDFS.range, XSD.string))
g.add((PJ_SDM.text, RDFS.label, Literal("text")))


g.add((PJ_SDM.tweet_by, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.tweet_by, RDFS.range, PJ_SDM.Tweet_user))
g.add((PJ_SDM.tweet_by, RDFS.label, Literal("tweet_by")))


g.add((PJ_SDM.tweet_time, RDFS.domain, PJ_SDM.Tweet))
g.add((PJ_SDM.tweet_time, RDFS.range, PJ_SDM.Time))
g.add((PJ_SDM.tweet_time, RDFS.label, Literal("tweet_time")))




#################################################################
#    Classes
#################################################################

###  http://www.gra.fo/schema/untitled-ekg#Company
gf:Company rdf:type owl:Class ;
           rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
           rdfs:label "company" .


###  http://www.gra.fo/schema/untitled-ekg#Mentioned_user
gf:Mentioned_user rdf:type owl:Class ;
                  rdfs:subClassOf gf:Person ;
                  rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                  rdfs:label "mentioned_user" .


###  http://www.gra.fo/schema/untitled-ekg#Person
gf:Person rdf:type owl:Class ;
          rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
          rdfs:label "person" .


###  http://www.gra.fo/schema/untitled-ekg#Stock_data
gf:Stock_data rdf:type owl:Class ;
              rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
              rdfs:label "stock_data" .


###  http://www.gra.fo/schema/untitled-ekg#Stock_market
gf:Stock_market rdf:type owl:Class ;
                rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                rdfs:label "stock_market" .


###  http://www.gra.fo/schema/untitled-ekg#Time
gf:Time rdf:type owl:Class ;
        rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
        rdfs:label "time" .


###  http://www.gra.fo/schema/untitled-ekg#Tweet
gf:Tweet rdf:type owl:Class ;
         rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
         rdfs:label "tweet" .


###  http://www.gra.fo/schema/untitled-ekg#Tweet_user
gf:Tweet_user rdf:type owl:Class ;
              rdfs:subClassOf gf:Person ;
              rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
              rdfs:label "tweet_user" .


###  http://www.w3.org/2001/XMLSchema#float
xsd:float rdf:type owl:Class ;
          rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
          rdfs:label "xsd:float" .


###  http://www.w3.org/2001/XMLSchema#float_50cb627e-a666-4582-a646-9f05d8fc283e
xsd:float_50cb627e-a666-4582-a646-9f05d8fc283e rdf:type owl:Class ;
                                               rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                               rdfs:label "xsd:float" .


###  http://www.w3.org/2001/XMLSchema#float_5ec01329-19b3-4c31-a6b8-515ce053b9b4
xsd:float_5ec01329-19b3-4c31-a6b8-515ce053b9b4 rdf:type owl:Class ;
                                               rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                               rdfs:label "xsd:float" .


###  http://www.w3.org/2001/XMLSchema#float_dac2ae26-707a-45fa-877f-02c06260463f
xsd:float_dac2ae26-707a-45fa-877f-02c06260463f rdf:type owl:Class ;
                                               rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                               rdfs:label "xsd:float" .


###  http://www.w3.org/2001/XMLSchema#float_fed13665-81ca-42e1-a48b-11cffd59c2d2
xsd:float_fed13665-81ca-42e1-a48b-11cffd59c2d2 rdf:type owl:Class ;
                                               rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                               rdfs:label "xsd:float" .


###  http://www.w3.org/2001/XMLSchema#integer
xsd:integer rdf:type owl:Class ;
            rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
            rdfs:label "xsd:integer" .


###  http://www.w3.org/2001/XMLSchema#integer_50fe0f7a-2065-4446-9bf7-2d8bf274d354
xsd:integer_50fe0f7a-2065-4446-9bf7-2d8bf274d354 rdf:type owl:Class ;
                                                 rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                 rdfs:label "xsd:integer" .


###  http://www.w3.org/2001/XMLSchema#integer_c0396110-d87e-4d2c-8a0d-fdac5c0b2722
xsd:integer_c0396110-d87e-4d2c-8a0d-fdac5c0b2722 rdf:type owl:Class ;
                                                 rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                 rdfs:label "xsd:integer" .


###  http://www.w3.org/2001/XMLSchema#integer_c7a37d16-3452-43ad-825c-25fe266e5eea
xsd:integer_c7a37d16-3452-43ad-825c-25fe266e5eea rdf:type owl:Class ;
                                                 rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                 rdfs:label "xsd:integer" .


###  http://www.w3.org/2001/XMLSchema#integer_d8713f6f-f0e9-4b8a-b607-8673268d4e77
xsd:integer_d8713f6f-f0e9-4b8a-b607-8673268d4e77 rdf:type owl:Class ;
                                                 rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                 rdfs:label "xsd:integer" .


###  http://www.w3.org/2001/XMLSchema#integer_efae5b9a-f1d2-49d5-bce8-e24ba54465da
xsd:integer_efae5b9a-f1d2-49d5-bce8-e24ba54465da rdf:type owl:Class ;
                                                 rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                 rdfs:label "xsd:integer" .


###  http://www.w3.org/2001/XMLSchema#string
xsd:string rdf:type owl:Class .


###  http://www.w3.org/2001/XMLSchema#string_5df54264-818b-4264-909f-6158cb2fad68
xsd:string_5df54264-818b-4264-909f-6158cb2fad68 rdf:type owl:Class ;
                                                rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                rdfs:label "xsd:string" .


###  http://www.w3.org/2001/XMLSchema#string_7bccc9c2-497c-45cb-b658-55a079d9ad50
xsd:string_7bccc9c2-497c-45cb-b658-55a079d9ad50 rdf:type owl:Class ;
                                                rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                rdfs:label "xsd:string" .


###  http://www.w3.org/2001/XMLSchema#string_95c31dc3-7f49-4dc6-ae40-79f3d52988ce
xsd:string_95c31dc3-7f49-4dc6-ae40-79f3d52988ce rdf:type owl:Class ;
                                                rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                rdfs:label "xsd:string" .


###  http://www.w3.org/2001/XMLSchema#string_f248ec70-7888-4a12-a2cd-7538067a9500
xsd:string_f248ec70-7888-4a12-a2cd-7538067a9500 rdf:type owl:Class ;
                                                rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
                                                rdfs:label "xsd:string" .


###  http://www.w3.org/2001/XMLSchema#timestamp
xsd:timestamp rdf:type owl:Class ;
              rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
              rdfs:label "xsd:timestamp" .


#################################################################
#    Annotations
#################################################################

<http://www.gra.fo/schema/untitled-ekg> rdfs:comment "" ;
                                        rdfs:label "sense_stock" .


xsd:string rdfs:isDefinedBy <http://www.gra.fo/schema/untitled-ekg> ;
           rdfs:label "xsd:string" .


###  Generated by the OWL API (version 5.1.17) https://github.com/owlcs/owlapi/
# Out:
#   File "<ipython-input-2-f086b5f660f6>", line 10
#     gf:close rdf:type owl:ObjectProperty ;
#              ^
# SyntaxError: invalid syntax

# %%
from rdflib import Graph,Literal,RDF,URIRef
from rdflib.namespace import FOAF,XSD,RDFS
from rdflib import Namespace

# %%
# initialize the graph
g = Graph()

# Namespace is used for the graph general URIref
# We can add are classes (Concepts) with kg_sdm uri (/Author, /Submission, /Chair) etc.
KG_SDM = Namespace("http://kg_sdm.org/")
# bind for the better readability
g.bind("kg_sdm",KG_SDM)


#======================================================================================================
# Properties
# By defining domain and ranges the classes and properties will be automaticly infered 


g.add((KG_SDM.comment, RDFS.domain, KG_SDM.DecisionProcess))
g.add((KG_SDM.comment, RDFS.range, XSD.string))
g.add((KG_SDM.comment, RDFS.label, Literal("comment")))


g.add((KG_SDM.goes_through, RDFS.domain, KG_SDM.Submission))
g.add((KG_SDM.goes_through, RDFS.range, KG_SDM.DecisionProcess))
g.add((KG_SDM.goes_through, RDFS.label, Literal("goes_through")))


g.add((KG_SDM.handles, RDFS.domain, KG_SDM.Handler))
g.add((KG_SDM.handles, RDFS.range, KG_SDM.Venue))
g.add((KG_SDM.handles, RDFS.label, Literal("handles")))


g.add((FOAF.name, RDFS.domain, FOAF.Person))
g.add((FOAF.name, RDFS.range, XSD.string))
g.add((FOAF.name, RDFS.label, Literal("name")))


g.add((KG_SDM.of_type, RDFS.domain, KG_SDM.Submission))
g.add((KG_SDM.of_type, RDFS.range, KG_SDM.PaperType))
g.add((KG_SDM.of_type, RDFS.label, Literal("of_type")))


g.add((KG_SDM.paper_title, RDFS.domain, KG_SDM.Submission))
g.add((KG_SDM.paper_title, RDFS.range, XSD.string))
g.add((KG_SDM.paper_title, RDFS.label, Literal("paper_title")))


g.add((KG_SDM.paper_year, RDFS.domain, KG_SDM.Submission))
g.add((KG_SDM.paper_year, RDFS.range, XSD.integer))
g.add((KG_SDM.paper_year, RDFS.label, Literal("paper_year")))


g.add((KG_SDM.publication_title, RDFS.domain, KG_SDM.Publication))
g.add((KG_SDM.publication_title, RDFS.range, XSD.string))
g.add((KG_SDM.publication_title, RDFS.label, Literal("publication_title")))


g.add((KG_SDM.publication_year, RDFS.domain, KG_SDM.Publication))
g.add((KG_SDM.publication_year, RDFS.range, XSD.integer))
g.add((KG_SDM.publication_year, RDFS.label, Literal("publication_year")))


g.add((KG_SDM.published_in, RDFS.domain, KG_SDM.Submission))
g.add((KG_SDM.published_in, RDFS.range, KG_SDM.Publication))
g.add((KG_SDM.published_in, RDFS.label, Literal("published_in")))


g.add((KG_SDM.related_to, RDFS.domain, KG_SDM.Submission))
g.add((KG_SDM.related_to, RDFS.range, KG_SDM.Keyword))
g.add((KG_SDM.related_to, RDFS.label, Literal("related_to")))


g.add((KG_SDM.participates_in, RDFS.domain, KG_SDM.Reviewers))
g.add((KG_SDM.participates_in, RDFS.range, KG_SDM.DecisionProcess))
g.add((KG_SDM.participates_in, RDFS.label, Literal("participates_in")))


g.add((KG_SDM.school, RDFS.domain, KG_SDM.Academic))
g.add((KG_SDM.school, RDFS.range, XSD.string))
g.add((KG_SDM.school, RDFS.label, Literal("school")))


g.add((KG_SDM.submitted_to, RDFS.domain, KG_SDM.Submission))
g.add((KG_SDM.submitted_to, RDFS.range, KG_SDM.Venue))
g.add((KG_SDM.submitted_to, RDFS.label, Literal("submitted_to")))


g.add((KG_SDM.venue_title, RDFS.domain, KG_SDM.Venue))
g.add((KG_SDM.venue_title, RDFS.range, XSD.string))
g.add((KG_SDM.venue_title, RDFS.label, Literal("venue_title")))


g.add((KG_SDM.writes, RDFS.domain, KG_SDM.Author))
g.add((KG_SDM.writes, RDFS.range, KG_SDM.Submission))
g.add((KG_SDM.writes, RDFS.label, Literal("writes")))



#=================================================================================================================
# Subclasses
# by defining subclasses the parent and child classes will be automaticaly infered



######### Person Subclasses #######
g.add((KG_SDM.Academic,RDFS.subClassOf,FOAF.Person))
g.add((KG_SDM.Academic, RDFS.label, Literal("Academic")))


g.add((KG_SDM.Author,RDFS.subClassOf,KG_SDM.Academic))
g.add((KG_SDM.Academic, RDFS.label, Literal("Author")))


g.add((KG_SDM.Reviewers,RDFS.subClassOf,KG_SDM.Academic))
g.add((KG_SDM.Reviewers, RDFS.label, Literal("Reviewers")))


g.add((KG_SDM.Handler,RDFS.subClassOf,KG_SDM.Academic))
g.add((KG_SDM.Handler, RDFS.label, Literal("Handler")))


g.add((KG_SDM.Chair,RDFS.subClassOf,KG_SDM.Handler))
g.add((KG_SDM.Chair, RDFS.label, Literal("Chair")))


g.add((KG_SDM.Editor,RDFS.subClassOf,KG_SDM.Handler))
g.add((KG_SDM.Editor, RDFS.label, Literal("Editor")))



######### Venue Subclasses #######
g.add((KG_SDM.Conference,RDFS.subClassOf,KG_SDM.Venue))
g.add((KG_SDM.Conference, RDFS.label, Literal("Conference")))


g.add((KG_SDM.Symposium,RDFS.subClassOf,KG_SDM.Conference))
g.add((KG_SDM.Symposium, RDFS.label, Literal("Symposium")))


g.add((KG_SDM.Workshop,RDFS.subClassOf,KG_SDM.Conference))
g.add((KG_SDM.Workshop, RDFS.label, Literal("Workshop")))


g.add((KG_SDM.Journal,RDFS.subClassOf,KG_SDM.Venue))
g.add((KG_SDM.Journal, RDFS.label, Literal("Journal")))



######### PaperType Subclasses #######
g.add((KG_SDM.Demo,RDFS.subClassOf,KG_SDM.PaperType))
g.add((KG_SDM.Demo, RDFS.label, Literal("Demo")))


g.add((KG_SDM.FullPaper,RDFS.subClassOf,KG_SDM.PaperType))
g.add((KG_SDM.FullPaper, RDFS.label, Literal("FullPaper")))


g.add((KG_SDM.Short,RDFS.subClassOf,KG_SDM.PaperType))
g.add((KG_SDM.Short, RDFS.label, Literal("Short")))


g.add((KG_SDM.Poster,RDFS.subClassOf,KG_SDM.PaperType))
g.add((KG_SDM.Poster, RDFS.label, Literal("Poster")))



######### Publication Subclasses #######
g.add((KG_SDM.Proceddings,RDFS.subClassOf,KG_SDM.Publication))
g.add((KG_SDM.Proceddings, RDFS.label, Literal("Proceddings")))


g.add((KG_SDM.Volume,RDFS.subClassOf,KG_SDM.Publication))
g.add((KG_SDM.Volume, RDFS.label, Literal("Volume")))



######### Keyword Subclasses #######
g.add((KG_SDM.ML,RDFS.subClassOf,KG_SDM.Keyword))
g.add((KG_SDM.ML, RDFS.label, Literal("ML")))


g.add((KG_SDM.NLP,RDFS.subClassOf,KG_SDM.Keyword))
g.add((KG_SDM.NLP, RDFS.label, Literal("NLP")))


g.add((KG_SDM.Graph,RDFS.subClassOf,KG_SDM.Keyword))
g.add((KG_SDM.GRAPH, RDFS.label, Literal("Graph")))


g.add((KG_SDM.Database,RDFS.subClassOf,KG_SDM.Keyword))
g.add((KG_SDM.Database, RDFS.label, Literal("Database")))


# ===================================================================================================================
# Saving RDFS graph (TBOX)

save_format = "ttl"
file_name = "tbox.ttl"
g.serialize(file_name, format=save_format)
